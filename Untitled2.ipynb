# %%
import yfinance as yf
import datetime as dt

qqq = yf.Ticker("QQQ")
spy = yf.Ticker("SPY")

# %%
df =yf.download(['QQQ'],  start = "2021-02-01" , end = "2021-02-04")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
x = dt.datetime.now()

# %%
def update(x):
    
    qqq = yf.Ticker("QQQ")
    spy = yf.Ticker("SPY")

    while(1):

        if x.hour == 6:
            # QQQ 2년간 데이터
            qqq_data = qqq.history(start=f"{x.year-2}-{x.month}-{x.day}",
                                   end=f"{x.year}-{x.month}-{x.day}")
            spy_data = spy.history(start=f"{x.year-2}-{x.month}-{x.day}", 
                                   end=f"{x.year}-{x.month}-{x.day}")

# %%
x.hour
# Out:
# 21

# %%
x.timetuple(1,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 x.timetuple(1,1)
#
# TypeError: timetuple() takes no arguments (2 given)

# %%
# QQQ 2년간 데이터
qqq_data = qqq.history(start=f"{x.year-1}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}")

# %%
# S&P 500 2년간 데이터
spy.history(start=f"{x.year-2}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-02 00:00:00-05:00  320.759491  322.857710  317.884097  320.759491
# 2020-11-03 00:00:00-05:00  324.149726  328.579352  320.846938  326.422821
# 2020-11-04 00:00:00-05:00  331.114739  337.992337  329.881059  333.718140
# 2020-11-05 00:00:00-05:00  339.255122  342.120793  338.885982  340.226532
# 2020-11-06 00:00:00-05:00  339.925399  341.460243  337.710586  340.148834
# ...                               ...         ...         ...         ...
# 2022-10-24 00:00:00-04:00  375.890015  380.059998  373.109985  378.869995
# 2022-10-25 00:00:00-04:00  378.790009  385.250000  378.670013  384.920013
# 2022-10-26 00:00:00-04:00  381.619995  387.579987  381.350006  382.019989
# 2022-10-27 00:00:00-04:00  383.070007  385.000000  379.329987  379.980011
# 2022-10-28 00:00:00-04:00  379.869995  389.519989  379.679993  389.019989
#
#                               Volume  Dividends  Stock Splits
# Date
# 2020-11-02 00:00:00-05:00   86068300        0.0             0
# 2020-11-03 00:00:00-05:00   93294200        0.0             0
# 2020-11-04 00:00:00-05:00  126959700        0.0             0
# 2020-11-05 00:00:00-05:00   82039700        0.0             0
# 2020-11-06 00:00:00-05:00   74973000        0.0             0
# ...                              ...        ...           ...
# 2022-10-24 00:00:00-04:00   85436900        0.0             0
# 2022-10-25 00:00:00-04:00   78846300        0.0             0
# 2022-10-26 00:00:00-04:00  104087300        0.0             0
# 2022-10-27 00:00:00-04:00   81971800        0.0             0
# 2022-10-28 00:00:00-04:00  100200100        0.0             0
#
# [502 rows x 7 columns]

# %%
df_qqq.index
# Out:
# DatetimeIndex(['2020-11-02 00:00:00-05:00', '2020-11-03 00:00:00-05:00',
#                '2020-11-04 00:00:00-05:00', '2020-11-05 00:00:00-05:00',
#                '2020-11-06 00:00:00-05:00', '2020-11-09 00:00:00-05:00',
#                '2020-11-10 00:00:00-05:00', '2020-11-11 00:00:00-05:00',
#                '2020-11-12 00:00:00-05:00', '2020-11-13 00:00:00-05:00',
#                ...
#                '2022-10-17 00:00:00-04:00', '2022-10-18 00:00:00-04:00',
#                '2022-10-19 00:00:00-04:00', '2022-10-20 00:00:00-04:00',
#                '2022-10-21 00:00:00-04:00', '2022-10-24 00:00:00-04:00',
#                '2022-10-25 00:00:00-04:00', '2022-10-26 00:00:00-04:00',
#                '2022-10-27 00:00:00-04:00', '2022-10-28 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=502, freq=None)

# %%
df_qqq
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-02 00:00:00-05:00  268.723273  270.374049  263.899397  266.874786
# 2020-11-03 00:00:00-05:00  268.831995  273.636113  267.724882  271.491058
# 2020-11-04 00:00:00-05:00  280.328225  285.448639  278.628007  283.610046
# 2020-11-05 00:00:00-05:00  290.153935  291.992557  288.641533  291.004059
# 2020-11-06 00:00:00-05:00  290.331824  291.962840  286.496445  291.221466
# ...                               ...         ...         ...         ...
# 2022-10-24 00:00:00-04:00  275.690002  279.399994  271.970001  278.450012
# 2022-10-25 00:00:00-04:00  279.410004  284.600006  277.899994  284.209991
# 2022-10-26 00:00:00-04:00  278.459991  283.980011  277.429993  277.929993
# 2022-10-27 00:00:00-04:00  276.790009  278.279999  272.339996  272.869995
# 2022-10-28 00:00:00-04:00  272.230011  281.700012  272.059998  281.220001
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-11-02 00:00:00-05:00  39987400        0.0             0
# 2020-11-03 00:00:00-05:00  43604100        0.0             0
# 2020-11-04 00:00:00-05:00  75728200        0.0             0
# 2020-11-05 00:00:00-05:00  52054200        0.0             0
# 2020-11-06 00:00:00-05:00  40959800        0.0             0
# ...                             ...        ...           ...
# 2022-10-24 00:00:00-04:00  63963600        0.0             0
# 2022-10-25 00:00:00-04:00  59014500        0.0             0
# 2022-10-26 00:00:00-04:00  63492400        0.0             0
# 2022-10-27 00:00:00-04:00  57760300        0.0             0
# 2022-10-28 00:00:00-04:00  62577000        0.0             0
#
# [502 rows x 7 columns]

# %%
import plotly.graph_objects as go

# %%
import pandas as pd
df_qqq = pd.DataFrame(qqq_data)

# %%
df_qqq.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
fig = go.Figure(data=[go.Candlestick(x=df.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="02d29692-7374-41bc-a006-917e88e9864f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("