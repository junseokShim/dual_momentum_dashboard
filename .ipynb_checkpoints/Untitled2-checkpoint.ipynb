# %%
import yfinance as yf
import datetime as dt

qqq = yf.Ticker("QQQ")
spy = yf.Ticker("SPY")

# %%
df =yf.download(['QQQ'],  start = "2021-02-01" , end = "2021-02-04")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
x = dt.datetime.now()

# %%
def update(x):
    
    qqq = yf.Ticker("QQQ")
    spy = yf.Ticker("SPY")

    while(1):

        if x.hour == 6:
            # QQQ 2년간 데이터
            qqq_data = qqq.history(start=f"{x.year-2}-{x.month}-{x.day}",
                                   end=f"{x.year}-{x.month}-{x.day}")
            spy_data = spy.history(start=f"{x.year-2}-{x.month}-{x.day}", 
                                   end=f"{x.year}-{x.month}-{x.day}")

# %%
x.hour
# Out:
# 15

# %%
# QQQ 2년간 데이터
qqq_data = qqq.history(start=f"{x.year-1}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}")

# %%
# S&P 500 2년간 데이터
spy_data = spy.history(start=f"{x.year-2}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}")

# %%
import plotly.graph_objects as go

# %%
import pandas as pd
df_qqq = pd.DataFrame(qqq_data)
df_spy = pd.DataFrame(spy_data)

# %%
df_spy
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-05 00:00:00-05:00  339.255122  342.120793  338.885982  340.226532
# 2020-11-06 00:00:00-05:00  339.925399  341.460243  337.710586  340.148834
# 2020-11-09 00:00:00-05:00  353.563973  353.962254  343.937299  344.423004
# 2020-11-10 00:00:00-05:00  343.383584  345.025269  340.488802  343.917877
# 2020-11-11 00:00:00-05:00  346.210418  347.337257  344.908732  346.472717
# ...                               ...         ...         ...         ...
# 2022-10-31 00:00:00-04:00  386.440002  388.399994  385.260010  386.209991
# 2022-11-01 00:00:00-04:00  390.140015  390.390015  383.290009  384.519989
# 2022-11-02 00:00:00-04:00  383.899994  388.630005  374.760010  374.869995
# 2022-11-03 00:00:00-04:00  371.470001  374.200012  368.790009  371.010010
# 2022-11-04 00:00:00-04:00  377.000000  378.869995  370.000000  376.350006
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df_qqq.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
fig = go.Figure(data=[go.Candlestick(x=df_qqq.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="633015f2-76ff-4222-bc08-064feee367f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("633015f2-76ff-4222-bc08-064feee367f2")) {                    Plotly.newPlot(                        "633015f2-76ff-4222-bc08-064feee367f2",                        [{"close":[322.4200134277344,327.67999267578125,326.3800048828125],"high":[323.5400085449219,328.8699951171875,330.20001220703125],"low":[316.0199890136719,325.30999755859375,326.32000732421875],"open":[318.1099853515625,325.4800109863281,329.82000732421875],"x":["2021-11-05T00:00:00-04:00","2021-11-08T00:00:00-05:00","2021-11-09T00:00:00-05:00","2021-11-10T00:00:00-05:00","2021-11-11T00:00:00-05:00","2021-11-12T00:00:00-05:00","2021-11-15T00:00:00-05:00","2021-11
# ...
