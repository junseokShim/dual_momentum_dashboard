# %%
import yfinance as yf
import datetime as dt
import pandas as pd

qqq = yf.Ticker("QQQ")
spy = yf.Ticker("SPY")

# %%
df =yf.download(['QQQ'],  start = "2021-02-01" , end = "2021-02-04")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
x = dt.datetime.now()

# %%
def update(x):
    
    qqq = yf.Ticker("QQQ")
    spy = yf.Ticker("SPY")

    while(1):

        if x.hour == 6:
            # QQQ 2년간 데이터
            qqq_data = qqq.history(start=f"{x.year-2}-{x.month}-{x.day}",
                                   end=f"{x.year}-{x.month}-{x.day}")
            spy_data = spy.history(start=f"{x.year-2}-{x.month}-{x.day}", 
                                   end=f"{x.year}-{x.month}-{x.day}")

# %%
x.hour
# Out:
# 13

# %%
# QQQ 2년간 데이터
qqq_data = qqq.history(start=f"{x.year-1}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}")

# %%
import numpy as np
new_array = np.array(qqq_data.index, dtype=np.datetime64)
# Out:
# /var/folders/p3/5cd6lj5j7q11887yhw6dp9cm0000gn/T/ipykernel_1973/2333659242.py:2: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   new_array = np.array(qqq_data.index, dtype=np.datetime64)

# %%
new_array[0].astype('str')
# Out:
# '2021-11-08T05:00:00.000000'

# %%
[new_array[i].astype('str')[:10] for i in range(len(new_array))]
# Out:
# ['2021-11-08',
#  '2021-11-09',
#  '2021-11-10',
#  '2021-11-11',
#  '2021-11-12',
#  '2021-11-15',
#  '2021-11-16',
#  '2021-11-17',
#  '2021-11-18',
#  '2021-11-19',
#  '2021-11-22',
#  '2021-11-23',
#  '2021-11-24',
#  '2021-11-26',
#  '2021-11-29',
#  '2021-11-30',
#  '2021-12-01',
#  '2021-12-02',
#  '2021-12-03',
#  '2021-12-06',
#  '2021-12-07',
#  '2021-12-08',
#  '2021-12-09',
#  '2021-12-10',
#  '2021-12-13',
#  '2021-12-14',
#  '2021-12-15',
#  '2021-12-16',
#  '2021-12-17',
#  '2021-12-20',
#  '2021-12-21',
#  '2021-12-22',
#  '2021-12-23',
#  '2021-12-27',
#  '2021-12-28',
#  '2021-12-29',
#  '2021-12-30',
#  '2021-12-31',
#  '2022-01-03',
#  '2022-01-04',
#  '2022-01-05',
#  '2022-01-06',
#  '2022-01-07',
#  '2022-01-10',
#  '2022-01-11',
#  '2022-01-12',
#  '2022-01-13',
#  '2022-01-14',
#  '2022-01-18',
#  '2022-01-19',
#  '2022-01-20',
#  '2022-01-21',
#  '2022-01-24',
#  '2022-01-25',
#  '2022-01-26',
#  '2022-01-27',
#  '2022-01-28',
#  '2022-01-31',
# ...

# %%
def yf_to_df(df, x):
    # S&P 500 2년간 데이터
    stock_data = pd.DataFrame(df.history(start=f"{x.year-2}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}"))

    new_stock_df = pd.DataFrame(stock_data.iloc[0:,:].values, columns = stock_data.columns)
    days = np.array(stock_data.index, dtype=np.datetime64)
    new_stock_df.index = [days[i].astype('str')[:10] for i in range(len(days))]
    
    return new_stock_df.to_json()

# %%
def yf_to_df(df, x):
    # S&P 500 2년간 데이터
    stock_data = pd.DataFrame(df.history(start=f"{x.year-2}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}"))

    new_stock_df = pd.DataFrame(stock_data.iloc[0:,:].values, columns = stock_data.columns)
    days = np.array(stock_data.index, dtype=np.datetime64)
    new_stock_df.index = [days[i].astype('str')[:10] for i in range(len(days))]
    
    return new_stock_df.to_json()


def stock_df():
    x = dt.datetime.now()
    
    # define으로 관리하고 싶은데...
    qqq = yf.Ticker("QQQ")
    spy = yf.Ticker("SPY")

    df_qqq = yf_to_df(qqq, x)
    df_spy = yf_to_df(spy, x)

    return df_qqq, df_spy

# %%
df_qqq, df_spy = stock_df()
# Out:
# /var/folders/p3/5cd6lj5j7q11887yhw6dp9cm0000gn/T/ipykernel_1973/207734531.py:6: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   days = np.array(stock_data.index, dtype=np.datetime64)
# /var/folders/p3/5cd6lj5j7q11887yhw6dp9cm0000gn/T/ipykernel_1973/207734531.py:6: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   days = np.array(stock_data.index, dtype=np.datetime64)

# %%
import json

def comb(x, stock1, stock2, per1=0.5, per2=0.5):
    per_lst = [per1, per2]

    stock1 = pd.DataFrame(json.loads(stock1))
    stock2 = pd.DataFrame(json.loads(stock2))

    df_total = (stock1*per1 + stock2*per2)/len(per_lst)
    df_total = df_total.to_json()
    
    return df_total

# %%
combs = comb(x, df_qqq, df_spy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 combs = comb(x, df_qqq, df_spy)
#
# Input In [54], in comb(x, stock1, stock2, per1, per2)
#       7 stock2 = pd.DataFrame(json.loads(stock2))
#       9 df_total = (stock1*per1 + stock2*per2)/len(per_lst)
# ---> 11 df_total = yf_to_df(df_total, x)
#      12 return df_total
#
# Input In [52], in yf_to_df(df, x)
#       1 def yf_to_df(df, x):
#       2     # S&P 500 2년간 데이터
# ----> 3     stock_data = pd.DataFrame(df.history(start=f"{x.year-2}-{x.month}-{x.day}", end=f"{x.year}-{x.month}-{x.day}"))
#       5     new_stock_df = pd.DataFrame(stock_data.iloc[0:,:].values, columns = stock_data.columns)
#       6     days = np.array(stock_data.index, dtype=np.datetime64)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
# ...

# %%
df_qqq[0]
# Out:
# '{'

# %%
spy["Open"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 spy["Open"]
#
# TypeError: string indices must be integers

# %%
pd.DataFrame(qqq)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 pd.DataFrame(qqq)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
new_spy.head(5)

# %%
import plotly.graph_objects as go

# %%
import pandas as pd
df_qqq = pd.DataFrame(qqq_data)
df_spy = pd.DataFrame(spy_data)

# %%
df_spy.index
# Out:
# (504,)

# %%
df_spy['Date'] = df_spy.index

# %%
df_spy.iloc[0:,:].values.shape
# Out:
# (504, 7)

# %%
new_spy = pd.DataFrame(df_spy.iloc[0:,:].values, columns = df_spy.columns)
new_spy['Date'] = df_spy.index

# %%
new_spy
# Out:
#            Open        High         Low       Close     Volume Dividends  \
# 0    339.255122  342.120793  338.885982  340.226532   82039700       0.0
# 1    339.925399  341.460243  337.710586  340.148834   74973000       0.0
# 2    353.563973  353.962254  343.937299  344.423004  172304200       0.0
# 3    343.383584  345.025269  340.488802  343.917877   85552000       0.0
# 4    346.210418  347.337257  344.908732  346.472717   58649000       0.0
# ..          ...         ...         ...         ...        ...       ...
# 499  386.440002  388.399994   385.26001  386.209991   96631300       0.0
# 500  390.140015  390.390015  383.290009  384.519989   85407600       0.0
# 501  383.899994  388.630005   374.76001  374.869995  126990400       0.0
# 502  371.470001  374.200012  368.790009   371.01001   87100100       0.0
# 503       377.0  378.869995       370.0  376.350006  103449600       0.0
#
#     Stock Splits                      Date
# 0              0 2020-11-05 00:00:00-05:00
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=new_spy['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="edf6e52a-5e88-4daf-a956-d655639368cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edf6e52a-5e88-4daf-a956-d655639368cf")) {                    Plotly.newPlot(                        "edf6e52a-5e88-4daf-a956-d655639368cf",                        [{"close":[322.4200134277344,327.67999267578125,326.3800048828125],"high":[323.5400085449219,328.8699951171875,330.20001220703125],"low":[316.0199890136719,325.30999755859375,326.32000732421875],"open":[318.1099853515625,325.4800109863281,329.82000732421875],"x":["2020-11-05T00:00:00-05:00","2020-11-06T00:00:00-05:00","2020-11-09T00:00:00-05:00","2020-11-10T00:00:00-05:00","2020-11-11T00:00:00-05:00","2020-11-12T00:00:00-05:00","2020-11-13T00:00:00-05:00","2020-11
# ...
